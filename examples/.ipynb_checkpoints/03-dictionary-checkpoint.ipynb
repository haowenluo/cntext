# %%
import cntext as ct
import os

sopmier = ct.SoPmi(cwd=os.getcwd(),
                   input_txt_file='data/sopmi_corpus.txt',  #raw corpus data，txt file.only support chinese data now.
                   seedword_txt_file='data/sopmi_seed_words.txt', #muanually selected seed words
                  )   

sopmier.sopmi()

# %%
import cntext as ct

# %%
help(ct.GloVe)
# Out:
# Help on function GloVe in module cntext.model.glove:
#
# GloVe(corpus_file, lang='chinese', stopwords_file=None, vector_size=100, window_size=15, min_count=5, max_memory=4.0, max_iter=15, x_max=10, only_binary=True)
#     使用Stanford GloVe代码工具训练GloVe模型。该函数会自动处理文本预处理(分词、去停词)、内存管理、参数调整等问题，确保训练过程顺利进行。
#
#     Args:
#         corpus_file (str): 输入语料文件路径（文本格式）。该文件为分词后的语料文件。utf-8编码。
#         lang (str, optional): 语料文件的语言类型，默认为 'chinese'。
#         stopwords_file (str, optional): 停用词txt文件路径，每行一个词。默认为 None。
#         vector_size (int): 词向量维度，默认 100。
#         window_size (int): 上下文窗口大小，默认 15。
#         min_count (int): 忽略出现次数低于此值的单词，默认 5。
#         max_memory (int): 可供使用的最大内存大小，默认 4.0 ，单位为GB；  该参数越大，训练越快。
#         max_iter (int): 训练的最大迭代次数，默认 15。
#         x_max (int): 共现矩阵中元素的最大计数值，默认 10。
#         only_binary (bool, optional): 是否只保存模型为二进制文件， 默认为True，只保存bin。 False时保存为txt和bin。
#
#
#     Returns: 训练好的 GloVe 模型。

# %%
import cntext as ct

ct.GloVe(corpus_file='data/w2v_corpus.txt', lang='english', vector_size=100, window_size=15)
# Out:
# Cache output/w2v_corpus_cache.txt Not Found or Empty, Preprocessing Corpus
# Processing Corpus: 100%|███████████████████| 1393/1393 [00:04<00:00, 328.10it/s]
# BUILDING VOCABULARY
# Start Training GloVe
# Using vocabulary of size 24381.
#
# COUNTING COOCCURRENCES
# Merging cooccurrence files: processed 16226848 lines.
#
# Using random seed 1758212186
# SHUFFLING COOCCURRENCES
# Merging temp files: processed 16226848 lines.
#
# TRAINING MODEL
# Read 16226848 lines.
# Using random seed 1758212189
# 09/19/25 - 12:16.30AM, iter: 001, cost: 0.071227
# 09/19/25 - 12:16.32AM, iter: 002, cost: 0.051115
# 09/19/25 - 12:16.33AM, iter: 003, cost: 0.044005
# 09/19/25 - 12:16.34AM, iter: 004, cost: 0.038440
# 09/19/25 - 12:16.36AM, iter: 005, cost: 0.034185
# 09/19/25 - 12:16.37AM, iter: 006, cost: 0.031259
# 09/19/25 - 12:16.39AM, iter: 007, cost: 0.029318
# 09/19/25 - 12:16.40AM, iter: 008, cost: 0.027921
# 09/19/25 - 12:16.42AM, iter: 009, cost: 0.026900
# ...

# %%
glove_e = ct.load_w2v('output/w2v_corpus-GloVe.100.15.bin')
# Out:
# Loading output/w2v_corpus-GloVe.100.15.bin...

# %%
glove_e.similar_by_key('nice')
# Out:
# [('great', 0.6994964480400085),
#  ('good', 0.6838533282279968),
#  ('congratulations', 0.6197530627250671),
#  ('terrific', 0.6106865406036377),
#  ('quarter.', 0.6005897521972656),
#  ('solid', 0.5820213556289673),
#  ('strong', 0.5778877139091492),
#  ('progress', 0.5700482130050659),
#  ('continued', 0.5692674517631531),
#  ('guys.', 0.5668314099311829)]

# %%
ct.GloVe(corpus_file='data/三体.txt', lang='chinese', vector_size=100, window_size=15)
# Out:
# Cache output/三体_cache.txt Not Found or Empty, Preprocessing Corpus
# Processing Corpus: 100%|████████████████| 24449/24449 [00:03<00:00, 7868.54it/s]
# BUILDING VOCABULARY
# Using vocabulary of size 7214.
#
# COUNTING COOCCURRENCES
# Start Training GloVe
# Merging cooccurrence files: processed 2438046 lines.
#
# Using random seed 1758212046
# SHUFFLING COOCCURRENCES
# Merging temp files: processed 2438046 lines.
#
# TRAINING MODEL
# Read 2438046 lines.
# Using random seed 1758212047
# 09/19/25 - 12:14.07AM, iter: 001, cost: 0.056261
# 09/19/25 - 12:14.07AM, iter: 002, cost: 0.050068
# 09/19/25 - 12:14.07AM, iter: 003, cost: 0.046339
# 09/19/25 - 12:14.08AM, iter: 004, cost: 0.044803
# 09/19/25 - 12:14.08AM, iter: 005, cost: 0.043238
# 09/19/25 - 12:14.08AM, iter: 006, cost: 0.041669
# 09/19/25 - 12:14.08AM, iter: 007, cost: 0.039996
# 09/19/25 - 12:14.08AM, iter: 008, cost: 0.038243
# 09/19/25 - 12:14.09AM, iter: 009, cost: 0.036440
# 09/19/25 - 12:14.09AM, iter: 010, cost: 0.034638
# ...

# %%
import cntext as ct
ct.Word2Vec(corpus_file='data/三体.txt', lang='chinese', vector_size=100, window_size=15)
# Out:
# Cache output/三体_cache.txt Not Found or Empty, Preprocessing Corpus
# Processing Corpus: 100%|████████████████| 24449/24449 [00:02<00:00, 8475.23it/s]
# Reading Preprocessed Corpus from output/三体_cache.txt
# Start Training Word2Vec
# Word2Vec Training Cost 3 s.
# Output Saved To: output/三体-Word2Vec.100.15.bin

# %%
glove_c = ct.load_w2v('output/三体-GloVe.100.15.bin')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/y0/4gqxky0s2t94x1c1qhlwr6100000gn/T/ipykernel_62746/3063421953.py in <cell line: 0>()
# ----> 1 glove_c = ct.load_w2v('output/三体-GloVe.100.15.bin')
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/cntext/model/utils.py in load_w2v(w2v_path)
#     359             wv = model.wv
#     360         else:
# --> 361             wv = KeyedVectors.load_word2vec_format(w2v_path, binary=binary)
#     362
#     363     else:
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/gensim/models/keyedvectors.py in load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, no_header)
#    1717
#    1718         """
# -> 1719         return _load_word2vec_format(
# ...

# %%
glove_c.similar_by_key('地球')
# Out:
# [('星舰', 0.7369127869606018),
#  ('演化', 0.6505491733551025),
#  ('治安', 0.6100241541862488),
#  ('招募', 0.605975329875946),
#  ('之子', 0.5945117473602295),
#  ('几十亿年', 0.5692088007926941),
#  ('调集', 0.563016951084137),
#  ('自然环境', 0.5586496591567993),
#  ('绝大部分', 0.5407715439796448),
#  ('文明', 0.5314014554023743)]

# %%
glove_c.similar_by_key('三体')
# Out:
# [('接纳', 0.7538015842437744),
#  ('叛军', 0.7474843263626099),
#  ('时后', 0.6962977647781372),
#  ('时前', 0.6876794099807739),
#  ('入侵', 0.6514280438423157),
#  ('组织', 0.6339157819747925),
#  ('厌倦', 0.6322422623634338),
#  ('星系', 0.627611517906189),
#  ('入侵者', 0.6217958331108093),
#  ('对三体', 0.6099292039871216)]

# %%
glove_c.similar_by_key('水滴')
# Out:
# [('九个', 0.6731771230697632),
#  ('尾部', 0.6630123257637024),
#  ('攻击', 0.6539689898490906),
#  ('追上', 0.6292110681533813),
#  ('一千公里', 0.6137961149215698),
#  ('穿透', 0.5894157290458679),
#  ('同行', 0.5827018618583679),
#  ('潜伏', 0.581785261631012),
#  ('击中', 0.5770249366760254),
#  ('摧毁', 0.5668109655380249)]

# %%
w2v_c = ct.load_w2v('output/三体-Word2Vec.100.15.bin')
# Out:
# Loading output/三体-Word2Vec.100.15.bin...

# %%
w2v_c.similar_by_key('水滴')
# Out:
# [('木星', 0.9938979744911194),
#  ('距离', 0.993663489818573),
#  ('轨道', 0.9928839802742004),
#  ('速度', 0.9925561547279358),
#  ('加速', 0.9895789623260498),
#  ('它们', 0.9894455075263977),
#  ('巨大', 0.9890027046203613),
#  ('运行', 0.9881178140640259),
#  ('物质', 0.9876113533973694),
#  ('大气层', 0.9871828556060791)]

# %% [markdown]
# ## 需要注意
#
# 训练出的w2v模型可以后续中使用。
#
# ```python
# from gensim.models import KeyedVectors
# #
# #w2v_model = KeyedVectors.load(w2v.model路径)
# w2v_model = KeyedVectors.load_word2vec_format('output/Word2Vec/w2v_model.txt')
#
# #找出最相近的词
# #w2v_model.most_similar_cosmul(positive=['woman', 'king'], negative=['man'])
# #w2v_model.most_similar_cosmul(positive=['女人', '国王'], negative=['男人'])
# ```
